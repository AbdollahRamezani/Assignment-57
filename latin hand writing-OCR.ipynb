# %%
import easyocr

# %%
reader = easyocr.Reader(['en']) 
result = reader.readtext('io/input/latin hand.jpg')  
result
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[20, 8], [163, 8], [163, 46], [20, 46]], 'BaPlincss', 0.11388573548289141),
#  ([[175, 13], [469, 13], [469, 58], [175, 58]],
#   'its heT-alwajs_abeut',
#   0.2575670784587291),
#  ([[15, 108], [153, 108], [153, 149], [15, 149]],
#   'haEliness',
#   0.19595471177743481),
#  ([[164, 116], [198, 116], [198, 146], [164, 146]], 'i5', 0.2820724077779146),
#  ([[208, 114], [350, 114], [350, 144], [208, 144]],
#   'emetimes',
#   0.9362364858776704),
#  ([[379, 115], [557, 115], [557, 152], [379, 152]],
#   'decD_Pleasulz',
#   0.19427568402750586),
#  ([[26, 152], [96, 152], [96, 182], [26, 182]], 'Afsm', 0.11456580460071564),
#  ([[110, 152], [162, 152], [162, 182], [110, 182]], 'rhe', 0.827742708871974),
#  ([[178, 152], [238, 152], [238, 180], [178, 180]],
#   'ha ve',
#   0.5168515005932521),
#  ([[256, 152], [316, 152], [316, 178], [256, 178]],
#   'nole',
# ...

# %%
result
# Out:
# [([[20, 8], [163, 8], [163, 46], [20, 46]], 'BaPlincss', 0.11388573548289141),
#  ([[175, 13], [469, 13], [469, 58], [175, 58]],
#   'its heT-alwajs_abeut',
#   0.2575670784587291),
#  ([[15, 108], [153, 108], [153, 149], [15, 149]],
#   'haEliness',
#   0.19595471177743481),
#  ([[164, 116], [198, 116], [198, 146], [164, 146]], 'i5', 0.2820724077779146),
#  ([[208, 114], [350, 114], [350, 144], [208, 144]],
#   'emetimes',
#   0.9362364858776704),
#  ([[379, 115], [557, 115], [557, 152], [379, 152]],
#   'decD_Pleasulz',
#   0.19427568402750586),
#  ([[26, 152], [96, 152], [96, 182], [26, 182]], 'Afsm', 0.11456580460071564),
#  ([[110, 152], [162, 152], [162, 182], [110, 182]], 'rhe', 0.827742708871974),
#  ([[178, 152], [238, 152], [238, 180], [178, 180]],
#   'ha ve',
#   0.5168515005932521),
#  ([[256, 152], [316, 152], [316, 178], [256, 178]],
#   'nole',
#   0.48308253288269043),
#  ([[467.08955369908847, 12.0835899750777],
#    [544.8809353009198, 33.91534771090672],
# ...

# %%
for item in result:  
  if item[2] > 0.5:
    print(item)
# Out:
# ([[208, 114], [350, 114], [350, 144], [208, 144]], 'emetimes', 0.9362364858776704)
# ([[110, 152], [162, 152], [162, 182], [110, 182]], 'rhe', 0.827742708871974)
# ([[178, 152], [238, 152], [238, 180], [178, 180]], 'ha ve', 0.5168515005932521)
